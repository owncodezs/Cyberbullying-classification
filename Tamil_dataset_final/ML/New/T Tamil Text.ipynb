# %% [markdown]
# # ML T

# %% [markdown]
# ## pre process

# %%
import pandas as pd
import numpy as np
import string
from nltk.corpus import stopwords
import spacy
from tqdm import tqdm
import copy
from sklearn.metrics import classification_report, confusion_matrix

# %%
# !wget https://raw.githubusercontent.com/owncodezs/Cyberbullying-classification/main/Tamil/translate_tamil.csv
# !wget https://raw.githubusercontent.com/Natkeeran/automated_tamil_text_classification/master/data/TamilNLP_TamilStopWords.txt
# !wget https://raw.githubusercontent.com/Natkeeran/automated_tamil_text_classification/master/data/custom_tamil_stop_words.txt
# Out:
# --2023-10-27 12:36:43--  https://raw.githubusercontent.com/owncodezs/Cyberbullying-classification/main/Tamil/translate_tamil.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13105123 (12M) [text/plain]
# Saving to: ‘translate_tamil.csv’
#
# translate_tamil.csv 100%[===================>]  12.50M  --.-KB/s    in 0.1s
#
# 2023-10-27 12:36:44 (103 MB/s) - ‘translate_tamil.csv’ saved [13105123/13105123]
#
# --2023-10-27 12:36:44--  https://raw.githubusercontent.com/Natkeeran/automated_tamil_text_classification/master/data/TamilNLP_TamilStopWords.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1963 (1.9K) [text/plain]
# Saving to: ‘TamilNLP_TamilStopWords.txt’
#
# TamilNLP_TamilStopW 100%[===================>]   1.92K  --.-KB/s    in 0s
#
# 2023-10-27 12:36:44 (17.8 MB/s) - ‘TamilNLP_TamilStopWords.txt’ saved [1963/1963]
#
# --2023-10-27 12:36:44--  https://raw.githubusercontent.com/Natkeeran/automated_tamil_text_classification/master/data/custom_tamil_stop_words.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1723 (1.7K) [text/plain]
# Saving to: ‘custom_tamil_stop_words.txt’
#
# custom_tamil_stop_w 100%[===================>]   1.68K  --.-KB/s    in 0s
#
# 2023-10-27 12:36:44 (15.1 MB/s) - ‘custom_tamil_stop_words.txt’ saved [1723/1723]

# %%
data = pd.read_csv("/content/translate_tamil.csv",
                   encoding = "utf-8",
                   engine = "python",
                   header = 0)

# %%
data.head()
# Out:
#    Unnamed: 0                                               text category  \
# 0           0  வணக்கம் டா மாப்ள வேதாரண்யத்துலேருந்து.. தரமான ...      NOT
# 1           1  அப்ப 96 to 2016; வரைக்கும் ரஜினி அரசியலுக்கு வ...      OFF
# 2           2  அருமை எவதொட்டாலும் வெட்டுடா அடிச்சா திருப்பி அ...      OFF
# 3           3  எங்கள் சாதியின் குல தெய்வம்  திரௌபதி அம்மன் அர...      NOT
# 4           4  trailer பார்த்துட்டு ஆய்த எழுத்து சூர்யா ஞாபகம...      NOT
#
#    Length  Word_count  mean_word_length  mean_sent_length  isenglish  \
# 0      72           8          8.125000              72.0      False
# 1      80          11          6.363636              80.0       True
# 2      68           8          7.625000              68.0      False
# 3      91          12          6.583333              91.0      False
# 4      76          10          6.500000              76.0       True
#
#                                            translate
# 0  வணக்கம் டா மாப்ள வேதாரண்யத்துலேருந்து.. தரமான ...
# 1  அப்ப 96 to 2016; வரைக்கும் ரஜினி அரசியலுக்கு வ...
# 2  அருமை எவதொட்டாலும் வெட்டுடா அடிச்சா திருப்பி அ...
# 3  எங்கள் சாதியின் குல தெய்வம்  திரௌபதி அம்மன் அர...
# 4  trailer பார்த்துட்டு ஆய்த எழுத்து சூர்யா ஞாபகம...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38214 entries, 0 to 38213
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        38214 non-null  int64
#  1   text              38214 non-null  object
#  2   category          38214 non-null  object
#  3   Length            38214 non-null  int64
#  4   Word_count        38214 non-null  int64
#  5   mean_word_length  38214 non-null  float64
#  6   mean_sent_length  38214 non-null  float64
#  7   isenglish         38214 non-null  bool
#  8   translate         38214 non-null  object
# dtypes: bool(1), float64(2), int64(3), object(3)
# memory usage: 2.4+ MB

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
def take_data_to_shower(tweet):
    tweet=str(tweet)

    noises = ['URL', '@USER', '\'ve', 'n\'t', '\'s', '\'m']

    for noise in noises:
        tweet = tweet.replace(noise, '')

    return tweet

# %%
def remove_emoticon(text):
        text=str(text)

        emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
        return emoji_pattern.sub(r'', text)

# %%
def remove_punc(text):
    text=str(text)
    table = str.maketrans("", "", string.punctuation)
    return text.translate(table)

# %%
def tokenize(tweet):
   tweet=str(tweet)
#
   lower_tweet = tweet.lower()
   return word_tokenize(lower_tweet)

# %%
def get_tamil_stop_words():
    swdf1 = pd.read_csv("TamilNLP_TamilStopWords.txt",  header=None)
    swdf2 = pd.read_csv("custom_tamil_stop_words.txt",  header=None)
    sw1 = swdf1[0].tolist()
    sw2 = swdf2[0].tolist()
    tamil_stop_words = list(set(sw1 + sw2))
    return tamil_stop_words

# %%
def remove_stop_words(tokens):
   clean_tokens = []
   newStopWords = get_tamil_stop_words()
#    newStopWords = [
#     "ஒரு", "இது", "அது", "அவர்", "நான்",
#     "நீங்கள்", "அவன்", "அவள்", "நமக்கு", "உங்களுக்கு",
#     "அவர்களுக்கு", "அவர்கள்", "அதில்", "இங்கு", "எப்போது",
#     "எப்படி", "என்னை", "உள்ள", "என்னுடைய", "உங்கள்",
#     "எமது", "இதை", "அந்த", "பொது", "மிகுந்த"
# ]
   stopWords = stopwords.words('english')
   stopWords.append(newStopWords)
  #  print(stopWords)

   for token in tokens:
       if token not in stopWords:
           if token.replace(' ', '') != '':
               if len(token) > 1:
                   clean_tokens.append(token)
   return ' '.join(clean_tokens)

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
##EMBEDDING##
def datacleen(data):
  tqdm.pandas(desc="Remove duplicates ")
  data.drop_duplicates(subset=['translate'], inplace=True)
  # tqdm.pandas(desc="To lower letter")
  # data = data.applymap(lambda x: x.lower() if isinstance(x, str) else x)

  tqdm.pandas(desc="Cleaning Data Phase I...")
  data['take_data_to_shower'] = data['translate'].progress_apply(take_data_to_shower)

  tqdm.pandas(desc="removing emoji...")
  data['remove_emoticon'] = data['take_data_to_shower'].progress_apply(remove_emoticon)

  # tqdm.pandas(desc="Translate...")
  # data['translate'] = data['remove_emoticon'].progress_apply(translate_to_tamil)

  tqdm.pandas(desc="removing punctuation...")
  data['remove_punc'] = data['remove_emoticon'].progress_apply(remove_punc)



  tqdm.pandas(desc="Tokenizing Data...")
  data['tokenize'] = data['remove_punc'].progress_apply(tokenize)

  tqdm.pandas(desc="Cleaning Data Phase II...")
  data['remove_stop_words'] = data['tokenize'].progress_apply(remove_stop_words)

  # tqdm.pandas(desc="Cleaning Data Phase III...")

  # data.drop(data[(data['category'] == 'unknown_state') | (data['category'] == 'not-tamil') |(data['category'] == 'non-tamil') |  (data['category'] == 'mixed_feelings')].index, inplace=True)
  # data.drop(data[(data['category'] == 'mixed_feelings')].index, inplace=True)
  # replacement_dict = {
  #     'positive': 0,
  #     'negative': 1,
  #     'mixed_feelings':-1,
  # }
  # # Replace values in the DataFrame
  # data['category'].replace(replacement_dict, inplace=True)


  # stem_and_lem ---> outlet
  return data
  # text_vector = clean_texts['tokens'].tolist()

# %%
data = datacleen(data)
data
# Out:
# Cleaning Data Phase I...: 100%|██████████| 38152/38152 [00:00<00:00, 414169.69it/s]
# removing emoji...: 100%|██████████| 38152/38152 [00:00<00:00, 195533.25it/s]
# removing punctuation...: 100%|██████████| 38152/38152 [00:00<00:00, 77070.42it/s]
# Tokenizing Data...: 100%|██████████| 38152/38152 [00:06<00:00, 6237.64it/s]
# Cleaning Data Phase II...: 100%|██████████| 38152/38152 [02:38<00:00, 240.30it/s]
#        Unnamed: 0                                               text category  \
# 0               0  வணக்கம் டா மாப்ள வேதாரண்யத்துலேருந்து.. தரமான ...      NOT
# 1               1  அப்ப 96 to 2016; வரைக்கும் ரஜினி அரசியலுக்கு வ...      OFF
# 2               2  அருமை எவதொட்டாலும் வெட்டுடா அடிச்சா திருப்பி அ...      OFF
# 3               3  எங்கள் சாதியின் குல தெய்வம்  திரௌபதி அம்மன் அர...      NOT
# 4               4  trailer பார்த்துட்டு ஆய்த எழுத்து சூர்யா ஞாபகம...      NOT
# ...           ...                                                ...      ...
# 38209       38209             Yov padam vera lvl la hit aaga poguthu      NOT
# 38210       38210                  Super star fans hit like  waiting      NOT
# 38211       38211       Seems to be Hindi Film Ek Tha Tiger Remake..      OFF
# 38212       38212                  Apa idhulla sk van yarum illayada      OFF
# 38213       38213  Karthi sir welcome to my kadavur village... Tq...      NOT
#
#        Length  Word_count  mean_word_length  mean_sent_length  isenglish  \
# 0          72           8          8.125000              72.0      False
# 1          80          11          6.363636              80.0       True
# 2          68           8          7.625000              68.0      False
# 3          91          12          6.583333              91.0      False
# 4          76          10          6.500000              76.0       True
# ...       ...         ...               ...               ...        ...
# 38209      38           8          3.875000              38.0       True
# 38210      33           6          4.500000              33.0       True
# 38211      44           9          4.000000              44.0       True
# 38212      33           6          4.666667              33.0       True
# 38213      53          10          4.400000              53.0       True
#
#                                                translate  \
# 0      வணக்கம் டா மாப்ள வேதாரண்யத்துலேருந்து.. தரமான ...
# 1      அப்ப 96 to 2016; வரைக்கும் ரஜினி அரசியலுக்கு வ...
# 2      அருமை எவதொட்டாலும் வெட்டுடா அடிச்சா திருப்பி அ...
# 3      எங்கள் சாதியின் குல தெய்வம்  திரௌபதி அம்மன் அர...
# 4      trailer பார்த்துட்டு ஆய்த எழுத்து சூர்யா ஞாபகம...
# ...                                                  ...
# 38209               Yov padam vera lvl la ஹிட் ஆக போகுது
# 38210  காத்திருப்பது போல் அதிர்ந்த சூப்பர் ஸ்டார் ரசி...
# 38211                  ஹிந்தி படம் ஏக் தா டைகர் ரீமேக்..
# 38212             அபா இதுல்லா எஸ்.கே வான் யாரும் இலையாடா
# 38213  என் கடவூர் கிராமத்திற்கு கார்த்தி சாரை வரவேற்க...
#
#                                      take_data_to_shower  \
# 0      வணக்கம் டா மாப்ள வேதாரண்யத்துலேருந்து.. தரமான ...
# 1      அப்ப 96 to 2016; வரைக்கும் ரஜினி அரசியலுக்கு வ...
# 2      அருமை எவதொட்டாலும் வெட்டுடா அடிச்சா திருப்பி அ...
# 3      எங்கள் சாதியின் குல தெய்வம்  திரௌபதி அம்மன் அர...
# 4      trailer பார்த்துட்டு ஆய்த எழுத்து சூர்யா ஞாபகம...
# ...                                                  ...
# 38209               Yov padam vera lvl la ஹிட் ஆக போகுது
# 38210  காத்திருப்பது போல் அதிர்ந்த சூப்பர் ஸ்டார் ரசி...
# 38211                  ஹிந்தி படம் ஏக் தா டைகர் ரீமேக்..
# 38212             அபா இதுல்லா எஸ்.கே வான் யாரும் இலையாடா
# 38213  என் கடவூர் கிராமத்திற்கு கார்த்தி சாரை வரவேற்க...
#
#                                          remove_emoticon  \
# 0      வணக்கம் டா மாப்ள வேதாரண்யத்துலேருந்து.. தரமான ...
# 1      அப்ப 96 to 2016; வரைக்கும் ரஜினி அரசியலுக்கு வ...
# 2      அருமை எவதொட்டாலும் வெட்டுடா அடிச்சா திருப்பி அ...
# 3      எங்கள் சாதியின் குல தெய்வம்  திரௌபதி அம்மன் அர...
# 4      trailer பார்த்துட்டு ஆய்த எழுத்து சூர்யா ஞாபகம...
# ...                                                  ...
# 38209               Yov padam vera lvl la ஹிட் ஆக போகுது
# 38210  காத்திருப்பது போல் அதிர்ந்த சூப்பர் ஸ்டார் ரசி...
# 38211                  ஹிந்தி படம் ஏக் தா டைகர் ரீமேக்..
# 38212             அபா இதுல்லா எஸ்.கே வான் யாரும் இலையாடா
# 38213  என் கடவூர் கிராமத்திற்கு கார்த்தி சாரை வரவேற்க...
#
#                                              remove_punc  \
# 0      வணக்கம் டா மாப்ள வேதாரண்யத்துலேருந்து தரமான சம...
# 1      அப்ப 96 to 2016 வரைக்கும் ரஜினி அரசியலுக்கு வர...
# 2      அருமை எவதொட்டாலும் வெட்டுடா அடிச்சா திருப்பி அ...
# 3      எங்கள் சாதியின் குல தெய்வம்  திரௌபதி அம்மன் அர...
# 4      trailer பார்த்துட்டு ஆய்த எழுத்து சூர்யா ஞாபகம...
# ...                                                  ...
# 38209               Yov padam vera lvl la ஹிட் ஆக போகுது
# 38210  காத்திருப்பது போல் அதிர்ந்த சூப்பர் ஸ்டார் ரசி...
# 38211                    ஹிந்தி படம் ஏக் தா டைகர் ரீமேக்
# 38212              அபா இதுல்லா எஸ்கே வான் யாரும் இலையாடா
# 38213  என் கடவூர் கிராமத்திற்கு கார்த்தி சாரை வரவேற்க...
#
#                                                 tokenize  \
# 0      [வணக்கம், டா, மாப்ள, வேதாரண்யத்துலேருந்து, தரம...
# 1      [அப்ப, 96, to, 2016, வரைக்கும், ரஜினி, அரசியலு...
# 2      [அருமை, எவதொட்டாலும், வெட்டுடா, அடிச்சா, திருப...
# 3      [எங்கள், சாதியின், குல, தெய்வம், திரௌபதி, அம்ம...
# 4      [trailer, பார்த்துட்டு, ஆய்த, எழுத்து, சூர்யா,...
# ...                                                  ...
# 38209      [yov, padam, vera, lvl, la, ஹிட், ஆக, போகுது]
# 38210  [காத்திருப்பது, போல், அதிர்ந்த, சூப்பர், ஸ்டார...
# 38211             [ஹிந்தி, படம், ஏக், தா, டைகர், ரீமேக்]
# 38212       [அபா, இதுல்லா, எஸ்கே, வான், யாரும், இலையாடா]
# 38213  [என், கடவூர், கிராமத்திற்கு, கார்த்தி, சாரை, வ...
#
#                                        remove_stop_words
# 0      வணக்கம் டா மாப்ள வேதாரண்யத்துலேருந்து தரமான சம...
# 1      அப்ப 96 2016 வரைக்கும் ரஜினி அரசியலுக்கு வருவே...
# 2      அருமை எவதொட்டாலும் வெட்டுடா அடிச்சா திருப்பி அ...
# 3      எங்கள் சாதியின் குல தெய்வம் திரௌபதி அம்மன் அரு...
# 4      trailer பார்த்துட்டு ஆய்த எழுத்து சூர்யா ஞாபகம...
# ...                                                  ...
# 38209               yov padam vera lvl la ஹிட் ஆக போகுது
# 38210  காத்திருப்பது போல் அதிர்ந்த சூப்பர் ஸ்டார் ரசி...
# 38211                    ஹிந்தி படம் ஏக் தா டைகர் ரீமேக்
# 38212              அபா இதுல்லா எஸ்கே வான் யாரும் இலையாடா
# 38213  என் கடவூர் கிராமத்திற்கு கார்த்தி சாரை வரவேற்க...
#
# [38152 rows x 14 columns]

# %% [markdown]
# ## Split

# %%
import numpy as np
from sklearn.model_selection import train_test_split
x = data["remove_stop_words"]
y = data["category"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=101, stratify=y )

# %% [markdown]
# ## process

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from gensim.models import Word2Vec
from sklearn.naive_bayes import BernoulliNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def show_confusion_matrix(matrixs,Classifier_text):
  plt.figure(figsize=(8, 6))
  sns.heatmap(matrixs, annot=True, fmt='d', cmap='Blues', cbar=False)
  plt.xlabel('Predicted Labels')
  plt.ylabel('True Labels')
  plt.title(f'Confusion Matrix -{Classifier_text}')
  plt.show()

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.naive_bayes import BernoulliNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from gensim.models import Word2Vec
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
def show_confusion_matrix(matrixs,Classifier_text):
  plt.figure(figsize=(8, 6))
  sns.heatmap(matrixs, annot=True, fmt='d', cmap='Blues', cbar=False)
  plt.xlabel('Predicted Labels')
  plt.ylabel('True Labels')
  plt.title(f'Confusion Matrix -{Classifier_text}')
  plt.show()

# %%
# Define your Word2Vec model
def train_word2vec(sentences, vector_size=100, window=5, min_count=1, workers=4):
    model = Word2Vec(sentences, vector_size=vector_size, window=window, min_count=min_count, workers=workers)
    return model

def document_vector(model, words):
    # Create a document vector by averaging word vectors
    vectors = [model.wv[word] for word in words if word in model.wv]
    return np.mean(vectors, axis=0) if vectors else np.zeros(model.vector_size)

def perform_classification(feature_extraction_type, X_train, X_test, y_train, y_test):
    if feature_extraction_type == "BOW":
        vectorizer = CountVectorizer()
    elif feature_extraction_type == "TF-IDF":
        vectorizer = TfidfVectorizer()
    elif feature_extraction_type == "Word2Vec":
        # Train Word2Vec model on your training data
        sentences = [text.split() for text in X_train]
        w2v_model = train_word2vec(sentences)

    if feature_extraction_type == "Word2Vec":
        X_train_fs = np.array([document_vector(w2v_model, text.split()) for text in X_train])
        X_test_fs = np.array([document_vector(w2v_model, text.split()) for text in X_test])
    else:
        X_train_fs = vectorizer.fit_transform(X_train)
        X_test_fs = vectorizer.transform(X_test)

    classifiers = [
        ("Bernoulli NB", BernoulliNB()),
        ("SVM", SVC(kernel='linear')),
        ("Logistic Regression", LogisticRegression(max_iter=1000)),
        ("KNN", KNeighborsClassifier(n_neighbors=100)),
        ("RandomForest", RandomForestClassifier(n_estimators=100)),
        ("Decision Tree", DecisionTreeClassifier())
    ]

    for classifier_name, classifier in classifiers:
        classifier.fit(X_train_fs, y_train)
        train_predictions = classifier.predict(X_train_fs)
        train_accuracy = accuracy_score(y_train, train_predictions)

        predictions = classifier.predict(X_test_fs)
        accuracy = accuracy_score(y_test, predictions)
        report = classification_report(y_test, predictions,zero_division =0)

        print(f"{classifier_name} Train Accuracy ({feature_extraction_type}): {train_accuracy:.2f}")
        print(f"{classifier_name} Test Accuracy ({feature_extraction_type}): {accuracy:.2f}")
        print(f"{classifier_name} Classification Report ({feature_extraction_type}):\n{report}")
        print(f"{classifier_name} Classification Report ({feature_extraction_type}):\n{confusion_matrix(y_test, predictions)}")
        # show_confusion_matrix(confusion_matrix(y_test, predictions),classifier_name)
        print(f"{classifier_name} Confusion Matrix ({feature_extraction_type})")
        print("\n\n")

# %%
# Before add stop word
perform_classification("BOW",x_train, x_test, y_train, y_test)
# Out:
# Bernoulli NB Train Accuracy (BOW): 0.80
# Bernoulli NB Test Accuracy (BOW): 0.78
# Bernoulli NB Classification Report (BOW):
#               precision    recall  f1-score   support
#
#          NOT       0.80      0.95      0.86      9495
#          OFF       0.61      0.25      0.36      3096
#
#     accuracy                           0.78     12591
#    macro avg       0.70      0.60      0.61     12591
# weighted avg       0.75      0.78      0.74     12591
#
# Bernoulli NB Classification Report (BOW):
# [[8983  512]
#  [2307  789]]
# Bernoulli NB Confusion Matrix (BOW)
#
#
#
# SVM Train Accuracy (BOW): 0.85
# SVM Test Accuracy (BOW): 0.78
# SVM Classification Report (BOW):
#               precision    recall  f1-score   support
#
#          NOT       0.80      0.95      0.86      9495
#          OFF       0.61      0.25      0.36      3096
#
#     accuracy                           0.78     12591
#    macro avg       0.70      0.60      0.61     12591
# weighted avg       0.75      0.78      0.74     12591
#
# SVM Classification Report (BOW):
# [[8988  507]
#  [2317  779]]
# SVM Confusion Matrix (BOW)
#
#
#
# Logistic Regression Train Accuracy (BOW): 0.84
# Logistic Regression Test Accuracy (BOW): 0.78
# Logistic Regression Classification Report (BOW):
#               precision    recall  f1-score   support
#
#          NOT       0.80      0.94      0.87      9495
#          OFF       0.62      0.30      0.41      3096
#
#     accuracy                           0.78     12591
#    macro avg       0.71      0.62      0.64     12591
# weighted avg       0.76      0.78      0.75     12591
#
# Logistic Regression Classification Report (BOW):
# [[8932  563]
#  [2166  930]]
# Logistic Regression Confusion Matrix (BOW)
#
#
#
# KNN Train Accuracy (BOW): 0.75
# KNN Test Accuracy (BOW): 0.75
# KNN Classification Report (BOW):
#               precision    recall  f1-score   support
#
#          NOT       0.75      1.00      0.86      9495
#          OFF       1.00      0.00      0.00      3096
#
#     accuracy                           0.75     12591
#    macro avg       0.88      0.50      0.43     12591
# weighted avg       0.81      0.75      0.65     12591
#
# KNN Classification Report (BOW):
# [[9495    0]
#  [3094    2]]
# KNN Confusion Matrix (BOW)
#
#
#
# RandomForest Train Accuracy (BOW): 1.00
# RandomForest Test Accuracy (BOW): 0.77
# RandomForest Classification Report (BOW):
#               precision    recall  f1-score   support
#
#          NOT       0.78      0.96      0.86      9495
#          OFF       0.61      0.18      0.28      3096
#
#     accuracy                           0.77     12591
#    macro avg       0.70      0.57      0.57     12591
# weighted avg       0.74      0.77      0.72     12591
#
# RandomForest Classification Report (BOW):
# [[9125  370]
#  [2524  572]]
# RandomForest Confusion Matrix (BOW)
#
#
#
# Decision Tree Train Accuracy (BOW): 1.00
# Decision Tree Test Accuracy (BOW): 0.72
# Decision Tree Classification Report (BOW):
#               precision    recall  f1-score   support
#
#          NOT       0.81      0.83      0.82      9495
#          OFF       0.44      0.41      0.42      3096
#
#     accuracy                           0.72     12591
#    macro avg       0.62      0.62      0.62     12591
# weighted avg       0.72      0.72      0.72     12591
#
# Decision Tree Classification Report (BOW):
# [[7849 1646]
#  [1828 1268]]
# Decision Tree Confusion Matrix (BOW)

# %%
# After Add stop word
perform_classification("TF-IDF",x_train, x_test, y_train, y_test)
# Out:
# Bernoulli NB Train Accuracy (TF-IDF): 0.80
# Bernoulli NB Test Accuracy (TF-IDF): 0.78
# Bernoulli NB Classification Report (TF-IDF):
#               precision    recall  f1-score   support
#
#          NOT       0.80      0.95      0.86      9495
#          OFF       0.61      0.25      0.36      3096
#
#     accuracy                           0.78     12591
#    macro avg       0.70      0.60      0.61     12591
# weighted avg       0.75      0.78      0.74     12591
#
# Bernoulli NB Classification Report (TF-IDF):
# [[8983  512]
#  [2307  789]]
# Bernoulli NB Confusion Matrix (TF-IDF)
#
#
#
# SVM Train Accuracy (TF-IDF): 0.81
# SVM Test Accuracy (TF-IDF): 0.78
# SVM Classification Report (TF-IDF):
#               precision    recall  f1-score   support
#
#          NOT       0.79      0.96      0.87      9495
#          OFF       0.65      0.21      0.31      3096
#
#     accuracy                           0.78     12591
#    macro avg       0.72      0.59      0.59     12591
# weighted avg       0.75      0.78      0.73     12591
#
# SVM Classification Report (TF-IDF):
# [[9149  346]
#  [2456  640]]
# SVM Confusion Matrix (TF-IDF)
#
#
#
# Logistic Regression Train Accuracy (TF-IDF): 0.81
# Logistic Regression Test Accuracy (TF-IDF): 0.78
# Logistic Regression Classification Report (TF-IDF):
#               precision    recall  f1-score   support
#
#          NOT       0.80      0.95      0.87      9495
#          OFF       0.63      0.28      0.38      3096
#
#     accuracy                           0.78     12591
#    macro avg       0.71      0.61      0.63     12591
# weighted avg       0.76      0.78      0.75     12591
#
# Logistic Regression Classification Report (TF-IDF):
# [[8984  511]
#  [2237  859]]
# Logistic Regression Confusion Matrix (TF-IDF)
#
#
#
# KNN Train Accuracy (TF-IDF): 0.75
# KNN Test Accuracy (TF-IDF): 0.75
# KNN Classification Report (TF-IDF):
#               precision    recall  f1-score   support
#
#          NOT       0.75      1.00      0.86      9495
#          OFF       0.00      0.00      0.00      3096
#
#     accuracy                           0.75     12591
#    macro avg       0.38      0.50      0.43     12591
# weighted avg       0.57      0.75      0.65     12591
#
# KNN Classification Report (TF-IDF):
# [[9495    0]
#  [3096    0]]
# KNN Confusion Matrix (TF-IDF)
#
#
#
# RandomForest Train Accuracy (TF-IDF): 1.00
# RandomForest Test Accuracy (TF-IDF): 0.77
# RandomForest Classification Report (TF-IDF):
#               precision    recall  f1-score   support
#
#          NOT       0.78      0.97      0.87      9495
#          OFF       0.65      0.15      0.24      3096
#
#     accuracy                           0.77     12591
#    macro avg       0.71      0.56      0.55     12591
# weighted avg       0.75      0.77      0.71     12591
#
# RandomForest Classification Report (TF-IDF):
# [[9246  249]
#  [2632  464]]
# RandomForest Confusion Matrix (TF-IDF)
#
#
#
# Decision Tree Train Accuracy (TF-IDF): 1.00
# Decision Tree Test Accuracy (TF-IDF): 0.73
# Decision Tree Classification Report (TF-IDF):
#               precision    recall  f1-score   support
#
#          NOT       0.80      0.85      0.82      9495
#          OFF       0.44      0.37      0.40      3096
#
#     accuracy                           0.73     12591
#    macro avg       0.62      0.61      0.61     12591
# weighted avg       0.71      0.73      0.72     12591
#
# Decision Tree Classification Report (TF-IDF):
# [[8038 1457]
#  [1958 1138]]
# Decision Tree Confusion Matrix (TF-IDF)

# %%
# Call the function with the desired feature extraction method
perform_classification("Word2Vec", x_train, x_test, y_train, y_test)
# Out:
# Bernoulli NB Train Accuracy (Word2Vec): 0.65
# Bernoulli NB Test Accuracy (Word2Vec): 0.65
# Bernoulli NB Classification Report (Word2Vec):
#               precision    recall  f1-score   support
#
#          NOT       0.87      0.63      0.73      9495
#          OFF       0.39      0.72      0.50      3096
#
#     accuracy                           0.65     12591
#    macro avg       0.63      0.67      0.62     12591
# weighted avg       0.75      0.65      0.68     12591
#
# Bernoulli NB Classification Report (Word2Vec):
# [[5977 3518]
#  [ 874 2222]]
# Bernoulli NB Confusion Matrix (Word2Vec)
#
#
#
# SVM Train Accuracy (Word2Vec): 0.75
# SVM Test Accuracy (Word2Vec): 0.75
# SVM Classification Report (Word2Vec):
#               precision    recall  f1-score   support
#
#          NOT       0.75      1.00      0.86      9495
#          OFF       0.00      0.00      0.00      3096
#
#     accuracy                           0.75     12591
#    macro avg       0.38      0.50      0.43     12591
# weighted avg       0.57      0.75      0.65     12591
#
# SVM Classification Report (Word2Vec):
# [[9495    0]
#  [3096    0]]
# SVM Confusion Matrix (Word2Vec)
#
#
#
# Logistic Regression Train Accuracy (Word2Vec): 0.76
# Logistic Regression Test Accuracy (Word2Vec): 0.75
# Logistic Regression Classification Report (Word2Vec):
#               precision    recall  f1-score   support
#
#          NOT       0.76      0.98      0.86      9495
#          OFF       0.48      0.06      0.11      3096
#
#     accuracy                           0.75     12591
#    macro avg       0.62      0.52      0.49     12591
# weighted avg       0.69      0.75      0.67     12591
#
# Logistic Regression Classification Report (Word2Vec):
# [[9273  222]
#  [2895  201]]
# Logistic Regression Confusion Matrix (Word2Vec)
#
#
#
# KNN Train Accuracy (Word2Vec): 0.76
# KNN Test Accuracy (Word2Vec): 0.76
# KNN Classification Report (Word2Vec):
#               precision    recall  f1-score   support
#
#          NOT       0.77      0.97      0.86      9495
#          OFF       0.51      0.10      0.16      3096
#
#     accuracy                           0.76     12591
#    macro avg       0.64      0.53      0.51     12591
# weighted avg       0.70      0.76      0.69     12591
#
# KNN Classification Report (Word2Vec):
# [[9205  290]
#  [2793  303]]
# KNN Confusion Matrix (Word2Vec)
#
#
#
# RandomForest Train Accuracy (Word2Vec): 1.00
# RandomForest Test Accuracy (Word2Vec): 0.76
# RandomForest Classification Report (Word2Vec):
#               precision    recall  f1-score   support
#
#          NOT       0.78      0.94      0.86      9495
#          OFF       0.53      0.20      0.29      3096
#
#     accuracy                           0.76     12591
#    macro avg       0.66      0.57      0.57     12591
# weighted avg       0.72      0.76      0.72     12591
#
# RandomForest Classification Report (Word2Vec):
# [[8936  559]
#  [2470  626]]
# RandomForest Confusion Matrix (Word2Vec)
#
#
#
# Decision Tree Train Accuracy (Word2Vec): 1.00
# Decision Tree Test Accuracy (Word2Vec): 0.69
# Decision Tree Classification Report (Word2Vec):
#               precision    recall  f1-score   support
#
#          NOT       0.79      0.81      0.80      9495
#          OFF       0.37      0.35      0.36      3096
#
#     accuracy                           0.69     12591
#    macro avg       0.58      0.58      0.58     12591
# weighted avg       0.69      0.69      0.69     12591
#
# Decision Tree Classification Report (Word2Vec):
# [[7673 1822]
#  [2019 1077]]
# Decision Tree Confusion Matrix (Word2Vec)

# %% [markdown]
# ## ROC

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc, cohen_kappa_score
from sklearn.naive_bayes import BernoulliNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from gensim.models import Word2Vec
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import json
import itertools
import time

# %%
def train_word2vec(sentences, vector_size=100, window=5, min_count=1, workers=4):
    model = Word2Vec(sentences, vector_size=vector_size, window=window, min_count=min_count, workers=workers)
    return model

def document_vector(model, words):
    # Create a document vector by averaging word vectors
    vectors = [model.wv[word] for word in words if word in model.wv]
    return np.mean(vectors, axis=0) if vectors else np.zeros(model.vector_size)
# Map your labels to binary (0 and 1)
result={
    "dataset":"Plain dataset",
    "output":[]
}
def perform_classification_with_roc(feature_extraction_type, X_train, X_test, y_train, y_test):
    label_mapping = {'NOT': 0, 'OFF': 1}
    y_test_binary = y_test.map(label_mapping)
    plt.figure(figsize=(20, 16))
    colors = itertools.cycle(['b', 'g', 'r', 'c', 'm', 'y', 'k', 'purple', 'orange', 'pink', 'brown', 'teal'])
    for feature_extraction in feature_extraction_type:
        print("\n")
        print("-"*100)
        if feature_extraction == "BOW":
            vectorizer = CountVectorizer()
        elif feature_extraction == "TF-IDF":
            vectorizer = TfidfVectorizer()
        elif feature_extraction == "Word2Vec":
            # Train Word2Vec model on your training data
            sentences = [text.split() for text in X_train]
            w2v_model = train_word2vec(sentences)

        if feature_extraction == "Word2Vec":
            X_train_fs = np.array([document_vector(w2v_model, text.split()) for text in X_train])
            X_test_fs = np.array([document_vector(w2v_model, text.split()) for text in X_test])
        else:
            X_train_fs = vectorizer.fit_transform(X_train)
            X_test_fs = vectorizer.transform(X_test)
        classifiers = [
            ("Bernoulli NB", BernoulliNB()),
            ("SVM", SVC(kernel='linear', probability=True)),  # Enable probability estimates
            ("Logistic Regression", LogisticRegression(max_iter=1000)),
            ("KNN", KNeighborsClassifier(n_neighbors=100))
        ]
        result_feature_extraction = {"feature_extraction":feature_extraction,"reports":[]}
        for classifier_name, classifier in classifiers:
            print("\n")
            print("="*100)
            start_time = time.time()
            classifier.fit(X_train_fs, y_train)
            end_time = time.time()
            elapsed_time = end_time - start_time

            print(f"{classifier_name} ({feature_extraction}) took {elapsed_time:.2f} seconds to complete.")


            train_predictions = classifier.predict(X_train_fs)
            train_accuracy = accuracy_score(y_train, train_predictions)

            predictions = classifier.predict(X_test_fs)
            accuracy = accuracy_score(y_test, predictions)
            report = classification_report(y_test, predictions, zero_division=0)
            kappa = cohen_kappa_score(y_test, predictions)

            print(f"{classifier_name} Train Accuracy ({feature_extraction}): {train_accuracy:.2f}")
            print(f"{classifier_name} Test Accuracy ({feature_extraction}): {accuracy:.2f}")
            print(f"{classifier_name} Kappa ({feature_extraction}): {kappa:.2f}")
            print(f"{classifier_name} Confusion Matrix ({feature_extraction}):\n{confusion_matrix(y_test, predictions)}")
            print(f"{classifier_name} Classification Report ({feature_extraction}):\n{report}")

            if hasattr(classifier, "predict_proba"):
                y_scores = classifier.predict_proba(X_test_fs)[:, 1]
            else:
                y_scores = classifier.decision_function(X_test_fs)

            fpr, tpr, thresholds = roc_curve(y_test_binary, y_scores)
            roc_auc = auc(fpr, tpr)
            fpr, tpr, thresholds = roc_curve(y_test_binary, y_scores)
            roc_auc = auc(fpr, tpr)
            color = next(colors)
            # Plot the ROC curve with a label for the classifier
            plt.plot(fpr, tpr, color, label=f'{classifier_name} ({feature_extraction}) - AUC = {roc_auc:.2f}')
            output = {
                "classifier_name":classifier_name,
                "train_accuracy":train_accuracy,
                "accuracy":accuracy,
                "report":report,
                "kappa":kappa,
                "fpr":fpr.tolist(),
                "tpr":tpr.tolist(),
                "thresholds":thresholds.tolist(),
                "auc":roc_auc,
                "confusion_matrix":(confusion_matrix(y_test, predictions).tolist())
            }
            result_feature_extraction["reports"].append(output)
        result["output"].append(result_feature_extraction)

    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curves for {feature_extraction_types} with Different Classifiers')
    plt.legend(loc="lower right")
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.show()

# %%
# Create ROC curves for each feature extraction method
feature_extraction_types = ["BOW", "TF-IDF", "Word2Vec"]
perform_classification_with_roc(feature_extraction_types, x_train, x_test, y_train, y_test)
# Out:
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
# Bernoulli NB (BOW) took 0.08 seconds to complete.
# Bernoulli NB Train Accuracy (BOW): 0.80
# Bernoulli NB Test Accuracy (BOW): 0.78
# Bernoulli NB Kappa (BOW): 0.25
# Bernoulli NB Confusion Matrix (BOW):
# [[8983  512]
#  [2307  789]]
# Bernoulli NB Classification Report (BOW):
#               precision    recall  f1-score   support
#
#          NOT       0.80      0.95      0.86      9495
#          OFF       0.61      0.25      0.36      3096
#
#     accuracy                           0.78     12591
#    macro avg       0.70      0.60      0.61     12591
# weighted avg       0.75      0.78      0.74     12591
#
#
#
# ====================================================================================================
# SVM (BOW) took 785.72 seconds to complete.
# SVM Train Accuracy (BOW): 0.85
# SVM Test Accuracy (BOW): 0.78
# SVM Kappa (BOW): 0.25
# SVM Confusion Matrix (BOW):
# [[8988  507]
#  [2317  779]]
# SVM Classification Report (BOW):
#               precision    recall  f1-score   support
#
#          NOT       0.80      0.95      0.86      9495
#          OFF       0.61      0.25      0.36      3096
#
#     accuracy                           0.78     12591
#    macro avg       0.70      0.60      0.61     12591
# weighted avg       0.75      0.78      0.74     12591
#
#
#
# ====================================================================================================
# Logistic Regression (BOW) took 3.59 seconds to complete.
# Logistic Regression Train Accuracy (BOW): 0.84
# Logistic Regression Test Accuracy (BOW): 0.78
# Logistic Regression Kappa (BOW): 0.29
# Logistic Regression Confusion Matrix (BOW):
# [[8932  563]
#  [2166  930]]
# Logistic Regression Classification Report (BOW):
#               precision    recall  f1-score   support
#
#          NOT       0.80      0.94      0.87      9495
#          OFF       0.62      0.30      0.41      3096
#
#     accuracy                           0.78     12591
#    macro avg       0.71      0.62      0.64     12591
# weighted avg       0.76      0.78      0.75     12591
#
#
#
# ====================================================================================================
# KNN (BOW) took 0.03 seconds to complete.
# KNN Train Accuracy (BOW): 0.75
# KNN Test Accuracy (BOW): 0.75
# KNN Kappa (BOW): 0.00
# KNN Confusion Matrix (BOW):
# [[9495    0]
#  [3094    2]]
# KNN Classification Report (BOW):
#               precision    recall  f1-score   support
#
#          NOT       0.75      1.00      0.86      9495
#          OFF       1.00      0.00      0.00      3096
#
#     accuracy                           0.75     12591
#    macro avg       0.88      0.50      0.43     12591
# weighted avg       0.81      0.75      0.65     12591
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
# Bernoulli NB (TF-IDF) took 0.08 seconds to complete.
# Bernoulli NB Train Accuracy (TF-IDF): 0.80
# Bernoulli NB Test Accuracy (TF-IDF): 0.78
# Bernoulli NB Kappa (TF-IDF): 0.25
# Bernoulli NB Confusion Matrix (TF-IDF):
# [[8983  512]
#  [2307  789]]
# Bernoulli NB Classification Report (TF-IDF):
#               precision    recall  f1-score   support
#
#          NOT       0.80      0.95      0.86      9495
#          OFF       0.61      0.25      0.36      3096
#
#     accuracy                           0.78     12591
#    macro avg       0.70      0.60      0.61     12591
# weighted avg       0.75      0.78      0.74     12591
#
#
#
# ====================================================================================================
# SVM (TF-IDF) took 287.63 seconds to complete.
# SVM Train Accuracy (TF-IDF): 0.81
# SVM Test Accuracy (TF-IDF): 0.78
# SVM Kappa (TF-IDF): 0.22
# SVM Confusion Matrix (TF-IDF):
# [[9149  346]
#  [2456  640]]
# SVM Classification Report (TF-IDF):
#               precision    recall  f1-score   support
#
#          NOT       0.79      0.96      0.87      9495
#          OFF       0.65      0.21      0.31      3096
#
#     accuracy                           0.78     12591
#    macro avg       0.72      0.59      0.59     12591
# weighted avg       0.75      0.78      0.73     12591
#
#
#
# ====================================================================================================
# Logistic Regression (TF-IDF) took 0.72 seconds to complete.
# Logistic Regression Train Accuracy (TF-IDF): 0.81
# Logistic Regression Test Accuracy (TF-IDF): 0.78
# Logistic Regression Kappa (TF-IDF): 0.28
# Logistic Regression Confusion Matrix (TF-IDF):
# [[8984  511]
#  [2237  859]]
# Logistic Regression Classification Report (TF-IDF):
#               precision    recall  f1-score   support
#
#          NOT       0.80      0.95      0.87      9495
#          OFF       0.63      0.28      0.38      3096
#
#     accuracy                           0.78     12591
#    macro avg       0.71      0.61      0.63     12591
# weighted avg       0.76      0.78      0.75     12591
#
#
#
# ====================================================================================================
# KNN (TF-IDF) took 0.03 seconds to complete.
# KNN Train Accuracy (TF-IDF): 0.75
# KNN Test Accuracy (TF-IDF): 0.75
# KNN Kappa (TF-IDF): 0.00
# KNN Confusion Matrix (TF-IDF):
# [[9495    0]
#  [3096    0]]
# KNN Classification Report (TF-IDF):
#               precision    recall  f1-score   support
#
#          NOT       0.75      1.00      0.86      9495
#          OFF       0.00      0.00      0.00      3096
#
#     accuracy                           0.75     12591
#    macro avg       0.38      0.50      0.43     12591
# weighted avg       0.57      0.75      0.65     12591
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
# Bernoulli NB (Word2Vec) took 0.12 seconds to complete.
# Bernoulli NB Train Accuracy (Word2Vec): 0.64
# Bernoulli NB Test Accuracy (Word2Vec): 0.65
# Bernoulli NB Kappa (Word2Vec): 0.26
# Bernoulli NB Confusion Matrix (Word2Vec):
# [[5925 3570]
#  [ 896 2200]]
# Bernoulli NB Classification Report (Word2Vec):
#               precision    recall  f1-score   support
#
#          NOT       0.87      0.62      0.73      9495
#          OFF       0.38      0.71      0.50      3096
#
#     accuracy                           0.65     12591
#    macro avg       0.62      0.67      0.61     12591
# weighted avg       0.75      0.65      0.67     12591
#
#
#
# ====================================================================================================
# SVM (Word2Vec) took 444.38 seconds to complete.
# SVM Train Accuracy (Word2Vec): 0.75
# SVM Test Accuracy (Word2Vec): 0.75
# SVM Kappa (Word2Vec): 0.00
# SVM Confusion Matrix (Word2Vec):
# [[9495    0]
#  [3096    0]]
# SVM Classification Report (Word2Vec):
#               precision    recall  f1-score   support
#
#          NOT       0.75      1.00      0.86      9495
#          OFF       0.00      0.00      0.00      3096
#
#     accuracy                           0.75     12591
#    macro avg       0.38      0.50      0.43     12591
# weighted avg       0.57      0.75      0.65     12591
#
#
#
# ====================================================================================================
# Logistic Regression (Word2Vec) took 4.30 seconds to complete.
# Logistic Regression Train Accuracy (Word2Vec): 0.76
# Logistic Regression Test Accuracy (Word2Vec): 0.75
# Logistic Regression Kappa (Word2Vec): 0.06
# Logistic Regression Confusion Matrix (Word2Vec):
# [[9276  219]
#  [2886  210]]
# Logistic Regression Classification Report (Word2Vec):
#               precision    recall  f1-score   support
#
#          NOT       0.76      0.98      0.86      9495
#          OFF       0.49      0.07      0.12      3096
#
#     accuracy                           0.75     12591
#    macro avg       0.63      0.52      0.49     12591
# weighted avg       0.70      0.75      0.68     12591
#
#
#
# ====================================================================================================
# KNN (Word2Vec) took 0.05 seconds to complete.
# KNN Train Accuracy (Word2Vec): 0.76
# KNN Test Accuracy (Word2Vec): 0.76
# KNN Kappa (Word2Vec): 0.10
# KNN Confusion Matrix (Word2Vec):
# [[9210  285]
#  [2788  308]]
# KNN Classification Report (Word2Vec):
#               precision    recall  f1-score   support
#
#          NOT       0.77      0.97      0.86      9495
#          OFF       0.52      0.10      0.17      3096
#
#     accuracy                           0.76     12591
#    macro avg       0.64      0.53      0.51     12591
# weighted avg       0.71      0.76      0.69     12591

# %%
with open('result.json', 'w') as json_file:
    json.dump(result, json_file)
result
# Out:
# {'dataset': 'Plain dataset',
#  'output': [{'feature_extraction': 'BOW',
#    'reports': [{'classifier_name': 'Bernoulli NB',
#      'train_accuracy': 0.804154767027894,
#      'accuracy': 0.7761099197839727,
#      'report': '              precision    recall  f1-score   support\n\n         NOT       0.80      0.95      0.86      9495\n         OFF       0.61      0.25      0.36      3096\n\n    accuracy                           0.78     12591\n   macro avg       0.70      0.60      0.61     12591\nweighted avg       0.75      0.78      0.74     12591\n',
#      'kappa': 0.249706115405945,
#      'fpr': [0.0,
#       0.0,
#       0.0,
#       0.00010531858873091101,
#       0.00010531858873091101,
#       0.00042127435492364404,
#       0.00042127435492364404,
#       0.000526592943654555,
#       0.000526592943654555,
#       0.000631911532385466,
#       0.000631911532385466,
#       0.0007372301211163771,
#       0.0007372301211163771,
#       0.0008425487098472881,
#       0.0008425487098472881,
#       0.0009478672985781991,
#       0.0009478672985781991,
#       0.00105318588730911,
#       0.00105318588730911,
#       0.001263823064770932,
#       0.001263823064770932,
#       0.0014744602422327542,
#       0.0014744602422327542,
#       0.001579778830963665,
#       0.001579778830963665,
#       0.0016850974196945762,
#       0.0016850974196945762,
#       0.0018957345971563982,
#       0.0018957345971563982,
#       0.002001053185887309,
#       0.002001053185887309,
#       0.00210637177461822,
#       0.00210637177461822,
#       0.0022116903633491313,
#       0.0022116903633491313,
#       0.002317008952080042,
#       0.002317008952080042,
#       0.002422327540810953,
#       0.002422327540810953,
#       0.002527646129541864,
#       0.002527646129541864,
#       0.002738283307003686,
#       0.002738283307003686,
#       0.0029489204844655083,
#       0.0029489204844655083,
#       0.00315955766192733,
#       0.00315955766192733,
#       0.003264876250658241,
#       0.003264876250658241,
#       0.0033701948393891523,
#       0.0033701948393891523,
#       0.0034755134281200632,
#       0.0034755134281200632,
#       0.003580832016850974,
#       0.003580832016850974,
#       0.003686150605581885,
#       0.003686150605581885,
#       0.0037914691943127963,
#       0.0037914691943127963,
#       0.52,
#       0.51,
#       0.5,
#       0.49,
#       0.48,
#       0.47,
#       0.46,
#       0.45,
#       0.44,
#       0.43,
#       0.42,
#       0.41,
#       0.4,
#       0.39,
#       0.38,
#       0.37,
#       0.36,
#       0.35,
#       0.34,
#       0.33,
#       0.32,
#       0.31,
#       0.3,
#       0.29,
#       0.28,
#       0.27,
#       0.26,
#       0.25,
#       0.24,
#       0.23,
#       0.22,
#       0.21,
#       0.2,
#       0.19,
#       0.18,
#       0.17,
#       0.16,
#       0.15,
#       0.14,
#       0.13,
#       0.12,
#       0.11,
#       0.1,
#       0.09,
#       0.08,
#       0.07,
#       0.06,
#       0.05,
#       0.04,
#       0.03,
#       0.02,
#       0.01,
#       0.0],
#      'auc': 0.7421060384018244,
#      'confusion_matrix': [[9210, 285], [2788, 308]]}]}]}

# %%
X_train_10 = x_train[:500]
X_test_10 = x_test[:50]
y_train_10 = y_train[:500]
y_test_10 = y_test[:50]

# Enable multi-threading for Word2Vec training by setting the 'workers' parameter
feature_extraction_types = ["BOW", "TF-IDF", "Word2Vec"]
perform_classification_with_roc(feature_extraction_types, X_train_10, X_test_10, y_train_10, y_test_10)
# Out:
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
# Bernoulli NB (BOW) took 0.00 seconds to complete.
# Bernoulli NB Train Accuracy (BOW): 0.84
# Bernoulli NB Test Accuracy (BOW): 0.82
# Bernoulli NB Kappa (BOW): 0.00
# Bernoulli NB Confusion Matrix (BOW):
# [[41  0]
#  [ 9  0]]
# Bernoulli NB Classification Report (BOW):
#               precision    recall  f1-score   support
#
#          NOT       0.82      1.00      0.90        41
#          OFF       0.00      0.00      0.00         9
#
#     accuracy                           0.82        50
#    macro avg       0.41      0.50      0.45        50
# weighted avg       0.67      0.82      0.74        50
#
#
#
# ====================================================================================================
# SVM (BOW) took 0.12 seconds to complete.
# SVM Train Accuracy (BOW): 1.00
# SVM Test Accuracy (BOW): 0.80
# SVM Kappa (BOW): 0.18
# SVM Confusion Matrix (BOW):
# [[38  3]
#  [ 7  2]]
# SVM Classification Report (BOW):
#               precision    recall  f1-score   support
#
#          NOT       0.84      0.93      0.88        41
#          OFF       0.40      0.22      0.29         9
#
#     accuracy                           0.80        50
#    macro avg       0.62      0.57      0.58        50
# weighted avg       0.76      0.80      0.78        50
#
#
#
# ====================================================================================================
# Logistic Regression (BOW) took 0.04 seconds to complete.
# Logistic Regression Train Accuracy (BOW): 0.98
# Logistic Regression Test Accuracy (BOW): 0.86
# Logistic Regression Kappa (BOW): 0.32
# Logistic Regression Confusion Matrix (BOW):
# [[41  0]
#  [ 7  2]]
# Logistic Regression Classification Report (BOW):
#               precision    recall  f1-score   support
#
#          NOT       0.85      1.00      0.92        41
#          OFF       1.00      0.22      0.36         9
#
#     accuracy                           0.86        50
#    macro avg       0.93      0.61      0.64        50
# weighted avg       0.88      0.86      0.82        50
#
#
#
# ====================================================================================================
# KNN (BOW) took 0.00 seconds to complete.
# KNN Train Accuracy (BOW): 0.76
# KNN Test Accuracy (BOW): 0.82
# KNN Kappa (BOW): 0.00
# KNN Confusion Matrix (BOW):
# [[41  0]
#  [ 9  0]]
# KNN Classification Report (BOW):
#               precision    recall  f1-score   support
#
#          NOT       0.82      1.00      0.90        41
#          OFF       0.00      0.00      0.00         9
#
#     accuracy                           0.82        50
#    macro avg       0.41      0.50      0.45        50
# weighted avg       0.67      0.82      0.74        50
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
# Bernoulli NB (TF-IDF) took 0.00 seconds to complete.
# Bernoulli NB Train Accuracy (TF-IDF): 0.84
# Bernoulli NB Test Accuracy (TF-IDF): 0.82
# Bernoulli NB Kappa (TF-IDF): 0.00
# Bernoulli NB Confusion Matrix (TF-IDF):
# [[41  0]
#  [ 9  0]]
# Bernoulli NB Classification Report (TF-IDF):
#               precision    recall  f1-score   support
#
#          NOT       0.82      1.00      0.90        41
#          OFF       0.00      0.00      0.00         9
#
#     accuracy                           0.82        50
#    macro avg       0.41      0.50      0.45        50
# weighted avg       0.67      0.82      0.74        50
#
#
#
# ====================================================================================================
# SVM (TF-IDF) took 0.12 seconds to complete.
# SVM Train Accuracy (TF-IDF): 0.96
# SVM Test Accuracy (TF-IDF): 0.82
# SVM Kappa (TF-IDF): 0.30
# SVM Confusion Matrix (TF-IDF):
# [[38  3]
#  [ 6  3]]
# SVM Classification Report (TF-IDF):
#               precision    recall  f1-score   support
#
#          NOT       0.86      0.93      0.89        41
#          OFF       0.50      0.33      0.40         9
#
#     accuracy                           0.82        50
#    macro avg       0.68      0.63      0.65        50
# weighted avg       0.80      0.82      0.81        50
#
#
#
# ====================================================================================================
# Logistic Regression (TF-IDF) took 0.02 seconds to complete.
# Logistic Regression Train Accuracy (TF-IDF): 0.76
# Logistic Regression Test Accuracy (TF-IDF): 0.82
# Logistic Regression Kappa (TF-IDF): 0.00
# Logistic Regression Confusion Matrix (TF-IDF):
# [[41  0]
#  [ 9  0]]
# Logistic Regression Classification Report (TF-IDF):
#               precision    recall  f1-score   support
#
#          NOT       0.82      1.00      0.90        41
#          OFF       0.00      0.00      0.00         9
#
#     accuracy                           0.82        50
#    macro avg       0.41      0.50      0.45        50
# weighted avg       0.67      0.82      0.74        50
#
#
#
# ====================================================================================================
# KNN (TF-IDF) took 0.00 seconds to complete.
# KNN Train Accuracy (TF-IDF): 0.76
# KNN Test Accuracy (TF-IDF): 0.82
# KNN Kappa (TF-IDF): 0.00
# KNN Confusion Matrix (TF-IDF):
# [[41  0]
#  [ 9  0]]
# KNN Classification Report (TF-IDF):
#               precision    recall  f1-score   support
#
#          NOT       0.82      1.00      0.90        41
#          OFF       0.00      0.00      0.00         9
#
#     accuracy                           0.82        50
#    macro avg       0.41      0.50      0.45        50
# weighted avg       0.67      0.82      0.74        50
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
# Bernoulli NB (Word2Vec) took 0.02 seconds to complete.
# Bernoulli NB Train Accuracy (Word2Vec): 0.78
# Bernoulli NB Test Accuracy (Word2Vec): 0.74
# Bernoulli NB Kappa (Word2Vec): -0.12
# Bernoulli NB Confusion Matrix (Word2Vec):
# [[37  4]
#  [ 9  0]]
# Bernoulli NB Classification Report (Word2Vec):
#               precision    recall  f1-score   support
#
#          NOT       0.80      0.90      0.85        41
#          OFF       0.00      0.00      0.00         9
#
#     accuracy                           0.74        50
#    macro avg       0.40      0.45      0.43        50
# weighted avg       0.66      0.74      0.70        50
#
#
#
# ====================================================================================================
# SVM (Word2Vec) took 0.05 seconds to complete.
# SVM Train Accuracy (Word2Vec): 0.76
# SVM Test Accuracy (Word2Vec): 0.82
# SVM Kappa (Word2Vec): 0.00
# SVM Confusion Matrix (Word2Vec):
# [[41  0]
#  [ 9  0]]
# SVM Classification Report (Word2Vec):
#               precision    recall  f1-score   support
#
#          NOT       0.82      1.00      0.90        41
#          OFF       0.00      0.00      0.00         9
#
#     accuracy                           0.82        50
#    macro avg       0.41      0.50      0.45        50
# weighted avg       0.67      0.82      0.74        50
#
#
#
# ====================================================================================================
# Logistic Regression (Word2Vec) took 0.01 seconds to complete.
# Logistic Regression Train Accuracy (Word2Vec): 0.76
# Logistic Regression Test Accuracy (Word2Vec): 0.82
# Logistic Regression Kappa (Word2Vec): 0.00
# Logistic Regression Confusion Matrix (Word2Vec):
# [[41  0]
#  [ 9  0]]
# Logistic Regression Classification Report (Word2Vec):
#               precision    recall  f1-score   support
#
#          NOT       0.82      1.00      0.90        41
#          OFF       0.00      0.00      0.00         9
#
#     accuracy                           0.82        50
#    macro avg       0.41      0.50      0.45        50
# weighted avg       0.67      0.82      0.74        50
#
#
#
# ====================================================================================================
# KNN (Word2Vec) took 0.00 seconds to complete.
# KNN Train Accuracy (Word2Vec): 0.76
# KNN Test Accuracy (Word2Vec): 0.82
# KNN Kappa (Word2Vec): 0.00
# KNN Confusion Matrix (Word2Vec):
# [[41  0]
#  [ 9  0]]
# KNN Classification Report (Word2Vec):
#               precision    recall  f1-score   support
#
#          NOT       0.82      1.00      0.90        41
#          OFF       0.00      0.00      0.00         9
#
#     accuracy                           0.82        50
#    macro avg       0.41      0.50      0.45        50
# weighted avg       0.67      0.82      0.74        50
